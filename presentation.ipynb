# %% [markdown]
# # Intro
#
# ### What is Python?
#
# - Interpreted: runs directly without compilation
# - Interactive: supports direct execution and experimentation
# - Object-oriented: based on the concept of classes and objects
#
#
# ### Key Features
#
# Incorporates:
#
# - Modules
# - Exceptions
# - Dynamic typing
# - High-level data types
# - Classes
#
# Supports multiple paradigms:
# - Object-oriented
# - Procedural
# - Functional programming
#
# ### Why Python Stands Out
#
# - Clear and readable syntax
# - Portability
#
# Runs on many operating systems:
#
# - Unix / Linux
# - macOS
# - Windows
#
# Same code can often run with no modification across platforms

# %% [markdown]
# # Panda Section
#
# This section will showcase the basics of pandas, focusing on:
# - **Series**: one-dimensional labeled arrays
# - **DataFrame**: two-dimensional tabular data
#
# We'll explore creation, indexing, and operations.

# %%
import pandas as pd

# %% [markdown]
# ## 1. Series
# ### 1.1 Creating a Series

# %%
s1 = pd.Series([1, 3, 5, 0, 6, 8])
s2 = pd.Series({'a': 10, 'b': 20, 'c': 30})
s3 = pd.Series(data=[9, 4, 2, 0, 1, 8], index= ['a', 'b', 'c', 'd', 'e', 'f'])
print(s1)
print()
print(s2)
print()
print(s3)
# Out:
# 0    1
# 1    3
# 2    5
# 3    0
# 4    6
# 5    8
# dtype: int64
#
# a    10
# b    20
# c    30
# dtype: int64
#
# a    9
# b    4
# c    2
# d    0
# e    1
# f    8
# dtype: int64

# %% [markdown]
# ### 1.2 Accessing data

# %%
print('Access by custom index:', s2['b'])
print('Access by index:', s2.iloc[1])
print('Slicing first 2 rows:\n'+str(s2[:2]))
# Out:
# Access by custom index: 20
# Access by index: 20
# Slicing first 2 rows:
# a    10
# b    20
# dtype: int64

# %% [markdown]
# ### 1.3 Operations

# %%
s3 * 2
# Out:
# a    18
# b     8
# c     4
# d     0
# e     2
# f    16
# dtype: int64

# %% [markdown]
# ## 2. DataFrame

# %%
import pandas as pd

# %% [markdown]
# ### 2.1 Creating a DataFrame

# %%
df = pd.read_csv('adult.csv')

# %% [markdown]
# ### 2.2 Inspecting the DataFrame

# %%
df.head()
# Out:
#    age workclass     education marital.status         occupation  \
# 0   90         ?       HS-grad        Widowed                  ?
# 1   82   Private       HS-grad        Widowed    Exec-managerial
# 2   66         ?  Some-college        Widowed                  ?
# 3   54   Private       7th-8th       Divorced  Machine-op-inspct
# 4   41   Private  Some-college      Separated     Prof-specialty
#
#     relationship   race     sex  hours.per.week native.country income
# 0  Not-in-family  White  Female              40  United-States  <=50K
# 1  Not-in-family  White  Female              18  United-States  <=50K
# 2      Unmarried  Black  Female              40  United-States  <=50K
# 3      Unmarried  White  Female              40  United-States  <=50K
# 4      Own-child  White  Female              40  United-States  <=50K

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# education         object
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %%
# Number of rows and columns
df.shape
# Out:
# (32561, 11)

# %%
df.size
# Out:
# 358171

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'education', 'marital.status', 'occupation',
#        'relationship', 'race', 'sex', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   education       32561 non-null  object
#  3   marital.status  32561 non-null  object
#  4   occupation      32561 non-null  object
#  5   relationship    32561 non-null  object
#  6   race            32561 non-null  object
#  7   sex             32561 non-null  object
#  8   hours.per.week  32561 non-null  int64
#  9   native.country  32561 non-null  object
#  10  income          32561 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 2.7+ MB

# %%
df.describe()
# Out:
#                 age  hours.per.week
# count  32561.000000    32561.000000
# mean      38.581647       40.437456
# std       13.640433       12.347429
# min       17.000000        1.000000
# 25%       28.000000       40.000000
# 50%       37.000000       40.000000
# 75%       48.000000       45.000000
# max       90.000000       99.000000

# %% [markdown]
# ### 2.3 Data Transformation

# %%
df.replace('?', 'Unknown', inplace=True)

# %%
df['income'] = df['income'].replace('>50K', 'Yes')
df['income'] = df['income'].replace('<=50K', 'No')
df
# Out:
#        age workclass     education      marital.status         occupation  \
# 0       90   Unknown       HS-grad             Widowed            Unknown
# 1       82   Private       HS-grad             Widowed    Exec-managerial
# 2       66   Unknown  Some-college             Widowed            Unknown
# 3       54   Private       7th-8th            Divorced  Machine-op-inspct
# 4       41   Private  Some-college           Separated     Prof-specialty
# ...    ...       ...           ...                 ...                ...
# 32556   22   Private  Some-college       Never-married    Protective-serv
# 32557   27   Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 32558   40   Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 32559   58   Private       HS-grad             Widowed       Adm-clerical
# 32560   22   Private       HS-grad       Never-married       Adm-clerical
#
#         relationship   race     sex  hours.per.week native.country income
# 0      Not-in-family  White  Female              40  United-States     No
# 1      Not-in-family  White  Female              18  United-States     No
# 2          Unmarried  Black  Female              40  United-States     No
# 3          Unmarried  White  Female              40  United-States     No
# 4          Own-child  White  Female              40  United-States     No
# ...              ...    ...     ...             ...            ...    ...
# 32556  Not-in-family  White    Male              40  United-States     No
# 32557           Wife  White  Female              38  United-States     No
# 32558        Husband  White    Male              40  United-States    Yes
# 32559      Unmarried  White  Female              40  United-States     No
# 32560      Own-child  White    Male              20  United-States     No
#
# [32561 rows x 11 columns]

# %%
def categorize_age(age):
    if age < 25:
        return 'Young'
    elif 25 <= age < 45:
        return 'Adult'
    elif 45 <= age < 65:
        return 'Middle-Aged'
    else:
        return 'Senior'
df['age_group'] = df['age'].apply(categorize_age)
df
# Out:
#        age workclass     education      marital.status         occupation  \
# 0       90   Unknown       HS-grad             Widowed            Unknown
# 1       82   Private       HS-grad             Widowed    Exec-managerial
# 2       66   Unknown  Some-college             Widowed            Unknown
# 3       54   Private       7th-8th            Divorced  Machine-op-inspct
# 4       41   Private  Some-college           Separated     Prof-specialty
# ...    ...       ...           ...                 ...                ...
# 32556   22   Private  Some-college       Never-married    Protective-serv
# 32557   27   Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 32558   40   Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 32559   58   Private       HS-grad             Widowed       Adm-clerical
# 32560   22   Private       HS-grad       Never-married       Adm-clerical
#
#         relationship   race     sex  hours.per.week native.country income  \
# 0      Not-in-family  White  Female              40  United-States     No
# 1      Not-in-family  White  Female              18  United-States     No
# 2          Unmarried  Black  Female              40  United-States     No
# 3          Unmarried  White  Female              40  United-States     No
# 4          Own-child  White  Female              40  United-States     No
# ...              ...    ...     ...             ...            ...    ...
# 32556  Not-in-family  White    Male              40  United-States     No
# 32557           Wife  White  Female              38  United-States     No
# 32558        Husband  White    Male              40  United-States    Yes
# 32559      Unmarried  White  Female              40  United-States     No
# 32560      Own-child  White    Male              20  United-States     No
#
#          age_group
# 0           Senior
# 1           Senior
# 2           Senior
# 3      Middle-Aged
# 4            Adult
# ...            ...
# 32556        Young
# 32557        Adult
# 32558        Adult
# 32559  Middle-Aged
# 32560        Young
#
# [32561 rows x 12 columns]

# %%
df = df.drop(columns=['age'])

# %% [markdown]
# ### 2.4 Slicing and Selecting

# %%
# Select first 10 rows
df.head(10)
# Out:
#      workclass     education marital.status         occupation  \
# 0      Unknown       HS-grad        Widowed            Unknown
# 1      Private       HS-grad        Widowed    Exec-managerial
# 2      Unknown  Some-college        Widowed            Unknown
# 3      Private       7th-8th       Divorced  Machine-op-inspct
# 4      Private  Some-college      Separated     Prof-specialty
# 5      Private       HS-grad       Divorced      Other-service
# 6      Private          10th      Separated       Adm-clerical
# 7    State-gov     Doctorate  Never-married     Prof-specialty
# 8  Federal-gov       HS-grad       Divorced     Prof-specialty
# 9      Private  Some-college  Never-married       Craft-repair
#
#      relationship   race     sex  hours.per.week native.country income  \
# 0   Not-in-family  White  Female              40  United-States     No
# 1   Not-in-family  White  Female              18  United-States     No
# 2       Unmarried  Black  Female              40  United-States     No
# 3       Unmarried  White  Female              40  United-States     No
# 4       Own-child  White  Female              40  United-States     No
# 5       Unmarried  White  Female              45  United-States     No
# 6       Unmarried  White    Male              40  United-States     No
# 7  Other-relative  White  Female              20  United-States    Yes
# 8   Not-in-family  White  Female              40  United-States     No
# 9       Unmarried  White    Male              60        Unknown    Yes
#
#      age_group
# 0       Senior
# 1       Senior
# 2       Senior
# 3  Middle-Aged
# 4        Adult
# 5        Adult
# 6        Adult
# 7       Senior
# 8       Senior
# 9        Adult

# %%
# Select rows 20 to 30
df[20:31]
# Out:
#        workclass     education      marital.status        occupation  \
# 20       Private     Bachelors       Never-married   Exec-managerial
# 21       Private          11th           Separated             Sales
# 22       Private       HS-grad            Divorced             Sales
# 23       Private  Some-college  Married-civ-spouse  Transport-moving
# 24       Unknown       HS-grad  Married-civ-spouse           Unknown
# 25       Private     Assoc-voc  Married-civ-spouse      Craft-repair
# 26       Private       1st-4th  Married-civ-spouse      Craft-repair
# 27       Private       5th-6th  Married-civ-spouse     Other-service
# 28  Self-emp-inc          10th       Never-married  Transport-moving
# 29       Private          10th       Never-married    Prof-specialty
# 30       Private  Some-college           Separated     Other-service
#
#      relationship   race     sex  hours.per.week native.country income  \
# 20  Not-in-family  White    Male              40  United-States    Yes
# 21  Not-in-family  White  Female              42  United-States     No
# 22      Unmarried  White  Female              25  United-States     No
# 23        Husband  White    Male              40  United-States     No
# 24        Husband  White    Male              32  United-States     No
# 25        Husband  White    Male              40  United-States     No
# 26  Not-in-family  White    Male              32         Mexico     No
# 27        Husband  White    Male              40         Greece     No
# 28  Not-in-family  White    Male              50  United-States    Yes
# 29  Not-in-family  White    Male              90  United-States    Yes
# 30  Not-in-family  White    Male              40  United-States    Yes
#
#       age_group
# 20        Adult
# 21        Adult
# 22  Middle-Aged
# 23  Middle-Aged
# 24  Middle-Aged
# 25        Young
# 26        Adult
# 27  Middle-Aged
# 28        Adult
# 29        Adult
# 30        Young

# %%
df.loc[0:5, ['education', 'income', 'occupation']]
# Out:
#       education income         occupation
# 0       HS-grad     No            Unknown
# 1       HS-grad     No    Exec-managerial
# 2  Some-college     No            Unknown
# 3       7th-8th     No  Machine-op-inspct
# 4  Some-college     No     Prof-specialty
# 5       HS-grad     No      Other-service

# %%
df.iloc[0:5, 2:6]
# Out:
#   marital.status         occupation   relationship   race
# 0        Widowed            Unknown  Not-in-family  White
# 1        Widowed    Exec-managerial  Not-in-family  White
# 2        Widowed            Unknown      Unmarried  Black
# 3       Divorced  Machine-op-inspct      Unmarried  White
# 4      Separated     Prof-specialty      Own-child  White
